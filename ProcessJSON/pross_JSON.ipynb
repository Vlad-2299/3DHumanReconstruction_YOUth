# %%
import json
import os
import csv
import matplotlib.pyplot as plt
import numpy as np
import copy
import pandas as pd

# %%
keypoint_json_list = []

for json_ in os.listdir(os.getcwd()):
    if json_.endswith('.json'):
        keypoint_json_list.append(json_)

# %%
keypoint_json_list
# Out:
# ['Laura_0_00_results.json']

# %%
#Creates folders to store frame by frame detections per view

for name in keypoint_json_list:
    folder = name.split('.json')[0]
    if not os.path.exists(folder):
        os.makedirs(folder)

# %%
def calc_keypoint_overlap(key_a, key_b):
    #If value close to 0, then keypoints belong to the same person
    assert len(key_a) == len(key_b)
    mean = 0
    for k_a, k_b in zip(key_a, key_b):
        mean += abs(k_a - k_b)
    return mean/len(key_a)

# %%
def plot_detections(det_list):
    for det in det_list:
        plt.plot(det)
    plt.show()

def write_csv(keys, det_list):
    filename = 'detections.csv'

    df = pd.DataFrame()
    for i in range(len(det_list)):
        df[keys[i]] = det_list[i]
    print(df.to_string())
    df.to_csv(filename, index=False)


def compute_detections(keys):
    '''
     keypoint_list: List that will hold all the keypoint detections per each view  [view][frame][keypoints]
     ensure that:   -keypoint_list[view][frame][keypoints][0] corresponds to exclusively one of the agents
                    -keypoint_list[view][frame][keypoints][1] corresponds to exclusively one of the agents
                    -view indexation consistency^^
    
    '''
    keypoint_list = [] 

    for key in keys:
        detect_keypoint_list = [] #[frame][keypoints]
        frame_count = 0
        
        with open(key) as f:
            k = json.load(f)
        prev = k[0]['image_id'].split('.png')[0]
        last = k[-1]['image_id'].split('.png')[0]
        frame = []
        for id, det in enumerate(k):
            curr = det['image_id'].split('.png')[0]
            if curr==prev:
                frame.append(det)
                if curr==last:
                    if id==len(k)-1: #last element
                        detect_keypoint_list.append(frame.copy())
                        frame.clear()
                        frame_count += 1
            elif curr!=prev:
                detect_keypoint_list.append(frame.copy())
                frame.clear()
                frame_count += 1
                frame.append(det)
            prev=curr
        keypoint_list.append(detect_keypoint_list)

    return keypoint_list

# %%
def get_erronous_det(det_per_view, missing):
    '''
    det_per_view: list of lists that has the detection count for each frame
    missing: Boolean that chooses if we count the frames where detections are missing (TRUE), or the frames where there are excessive detecions (FALSE)
    '''
    miss_det = []
    for view in det_per_view:
        miss_det_view = []
        for idx, n_det in enumerate(view):
            if missing:
                if len(n_det) < 2:
                    miss_det_view.append(idx)
            else:
                if len(n_det) > 2:
                    miss_det_view.append(idx)
        miss_det.append(miss_det_view)
    return miss_det

# %%
def get_missing_detection_ranges(miss_det):
    miss_det_range = []

    for view in range(len(miss_det)):
        view_ranges = []
        interpolation_range = []
        for frame in miss_det[view]:
            if not interpolation_range:
                interpolation_range.append(frame)
                if frame == miss_det[view][-1]:
                    view_ranges.append(interpolation_range.copy())
            elif interpolation_range[-1] + 1 == frame:
                interpolation_range.append(frame)
            elif interpolation_range[-1] + 1 != frame:
                view_ranges.append(interpolation_range.copy())
                interpolation_range.clear()
                interpolation_range.append(frame)
                if frame == miss_det[view][-1]:
                    view_ranges.append(interpolation_range.copy())
        miss_det_range.append(view_ranges.copy())
        

    return miss_det_range

# %%
all_detections = compute_detections(keypoint_json_list)
missing_detections = get_erronous_det(all_detections, True)
excess_detections = get_erronous_det(all_detections, False)
missing_detection_ranges = get_missing_detection_ranges(missing_detections)

# %%
def identify_keypoint_index(current_det, prev_det):
    '''
    Mehtod that identifies the keypoints similarity in current frame, based on keypoints of previous/next frame
    0: current_det is more similar to the detection prev_det[0]
    1: current_det is more similar to the detection prev_det[1]
    '''
    assert len(current_det) == 1
    assert len(prev_det) == 2

    overlap_one = calc_keypoint_overlap(current_det[0]['keypoints'], prev_det[0]['keypoints'])
    overlap_two = calc_keypoint_overlap(current_det[0]['keypoints'], prev_det[1]['keypoints'])
    #print('Overlap with last index 0, ', overlap_one)
    #print('Overlap with last index 1, ', overlap_two)
    if overlap_one < overlap_two:
        return 0
    else:
        return 1

# %%
a = [1, 2]
b = [3, 1]

print(set(a) & set(b))
# Out:
# {1}

# %%
def correct_excess_det(ex_det, key_view_list):
    corrected_list = copy.deepcopy(key_view_list)

    assert len(ex_det) == len(corrected_list)
    

    for view, frame_list in enumerate(ex_det):
        for frame in frame_list:
            print('--------')
            print('Frame: ', frame)
            print('View: ', view)

            remove_by_worst_score = False
            match_idx = True
            
            if len(corrected_list[view][frame-1]) == 2:
                #Remove detection with least overlap
                list_cand_overlap = []
                idx_prev_det = []
                for prev_det in corrected_list[view][frame-1]:
                    #For loop gets the overlap between prev. detections (2) and current detections (>2)
                    idx_cand = []
                    overlap_cand = []
                    print('Prev idx: ', prev_det['idx'])
                    idx_prev_det.append(prev_det['idx'])
                    for candidate in corrected_list[view][frame]:
                        overlap = calc_keypoint_overlap(prev_det['keypoints'], candidate['keypoints'])
                        overlap_cand.append(overlap)
                        idx_cand.append(candidate['idx'])
                    print('Candidate idx ', idx_cand)
                    list_cand_overlap.append(overlap_cand.copy())

                assert len(list_cand_overlap) == 2

                curr_best_cand_idx = []
                for cand_result_list in list_cand_overlap:
                    #Gets the index of the current detection that best overlaps the prev. frame detection
                    print(cand_result_list)
                    curr_best_cand_idx.append(np.argmin(cand_result_list))

                print(curr_best_cand_idx)
                print(corrected_list[view][frame][curr_best_cand_idx[0]]['idx'], corrected_list[view][frame][curr_best_cand_idx[1]]['idx'])

                if len(curr_best_cand_idx) == len(set(curr_best_cand_idx)):
                    #If candidate detection is not the same
                    if list_cand_overlap[0][curr_best_cand_idx[0]] < 15 and list_cand_overlap[1][curr_best_cand_idx[1]] < 15:
                        corrected_list[view][frame].clear()
                        corrected_list[view][frame].append(key_view_list[view][frame][curr_best_cand_idx[0]])
                        corrected_list[view][frame].append(key_view_list[view][frame][curr_best_cand_idx[1]])
                        match_idx = False
                if match_idx:
                    candidate_idx = []
                    for prev_det in key_view_list[view][frame-1]:
                        for candidate in key_view_list[view][frame]:
                            if prev_det['idx'] == candidate['idx']:
                                candidate_idx.append(candidate)
                    if len(candidate_idx) == 2:
                        corrected_list[view][frame].clear()
                        corrected_list[view][frame] = copy.deepcopy(candidate_idx)
                    else:
                        remove_by_worst_score = True
            else:
                print('Prev frame does not have 2 detections')
                remove_by_worst_score = True
                
            if remove_by_worst_score: 
                print(f'Removing by score in frame')
                #Remove detection with least score
                first_conf = 0
                first_conf_det = None
                second_conf = 0
                second_conf_det = None
                for d in corrected_list[view][frame]:
                    print(d)
                    if d['score'] > first_conf:
                        if second_conf == 0:
                            second_conf = first_conf
                            second_conf_det = first_conf_det
                        first_conf = d['score']
                        first_conf_det = d
                    elif d['score'] > second_conf and d['score'] < first_conf:
                        second_conf = d['score']
                        second_conf_det = d
                corrected_list[view][frame].clear()
                print(first_conf_det['idx'], second_conf_det['idx'])
                corrected_list[view][frame].append(first_conf_det)
                corrected_list[view][frame].append(second_conf_det)

        assert len(corrected_list[view][frame]) == 2
    return corrected_list

# %%
corrected_key_view_list = correct_excess_det(excess_detections, all_detections)
# Out:
# --------
# Frame:  264
# View:  0
# Prev idx:  1
# Candidate idx  [1, 3, 2]
# Prev idx:  3
# Candidate idx  [1, 3, 2]
# [0.7586024961410425, 48.72624630404589, 48.00595924945978]
# [49.90090217207296, 2.582310668503245, 6.3372292428349075]
# [0, 1]
# 1 3
# --------
# Frame:  530
# View:  0
# Prev idx:  1
# Candidate idx  [1, 2, 4]
# Prev idx:  2
# Candidate idx  [1, 2, 4]
# [4.896273243121612, 49.93281988684948, 54.855284438301354]
# [54.23177910844485, 7.55885659578519, 1.6475703895856173]
# [0, 2]
# 1 4
# --------
# Frame:  531
# View:  0
# Prev idx:  1
# Candidate idx  [1, 2, 4]
# Prev idx:  4
# Candidate idx  [1, 2, 4]
# [0.0, 50.88264266114969, 55.04739683981125]
# [55.04739683981125, 7.5081647004072485, 0.0]
# [0, 2]
# 1 4
# --------
# Frame:  535
# View:  0
# Prev idx:  1
# Candidate idx  [1, 4, 2]
# Prev idx:  4
# Candidate idx  [1, 4, 2]
# [1.5734831549418278, 56.18803280095259, 52.18847855896904]
# [55.27051319640417, 1.0053798178067574, 5.973515294014644]
# [0, 1]
# 1 4
# --------
# Frame:  536
# View:  0
# Prev idx:  1
# Candidate idx  [1, 4, 2]
# Prev idx:  4
# Candidate idx  [1, 4, 2]
# [1.4772412998554034, 54.92374954009667, 51.46309124964934]
# [55.10778750441013, 1.0140291635806744, 5.674853191161767]
# [0, 1]
# 1 4
# --------
# Frame:  537
# View:  0
# Prev idx:  1
# Candidate idx  [1, 4, 2]
# Prev idx:  4
# Candidate idx  [1, 4, 2]
# [0.0, 55.00859929735844, 51.41526671556326]
# [55.00859929735844, 0.0, 5.632670834278449]
# [0, 1]
# 1 4
# --------
# Frame:  540
# View:  0
# Prev idx:  1
# Candidate idx  [1, 2, 4]
# Prev idx:  2
# Candidate idx  [1, 2, 4]
# [6.262094990947308, 50.498668018250896, 54.744145473990685]
# [49.23294537175351, 3.281814281995862, 8.198803782319793]
# [0, 1]
# 1 2
# --------
# Frame:  875
# View:  0
# Prev idx:  1
# Candidate idx  [1, 2, 5]
# Prev idx:  2
# Candidate idx  [1, 2, 5]
# [7.931767211510585, 55.193681677755634, 51.469652286324745]
# [61.82537914086611, 4.169947204490502, 20.196195266567745]
# [0, 1]
# 1 2
# --------
# Frame:  930
# View:  0
# Prev frame does not have 2 detections
# Removing by score in frame
# {'image_id': '00931.png', 'category_id': 1, 'keypoints': [433.7276306152344, 151.431640625, 0.9531975984573364, 446.4665222167969, 142.93905639648438, 0.951072096824646, 429.4813537597656, 134.4464874267578, 0.978482723236084, 459.20538330078125, 134.4464874267578, 0.6618448495864868, 416.74249267578125, 113.21504211425781, 0.8982239961624146, 450.7127990722656, 151.431640625, 0.9166116714477539, 382.7721862792969, 138.69277954101562, 0.9198327660560608, 450.7127990722656, 202.38710021972656, 0.8641619682312012, 374.27960205078125, 202.38710021972656, 0.8253902792930603, 463.45166015625, 253.34255981445312, 0.929975688457489, 416.74249267578125, 206.63339233398438, 0.9130952954292297, 365.7870178222656, 223.61854553222656, 0.8311895132064819, 314.8315734863281, 219.37225341796875, 0.8345522284507751, 395.51104736328125, 270.3277282714844, 0.621082603931427, 289.3538513183594, 295.8054504394531, 0.9262974858283997, 344.55560302734375, 283.06658935546875, 0.5202529430389404, 225.65951538085938, 257.5888671875, 0.7834445834159851, 454.9590759277344, 104.72246551513672, 0.9407914280891418, 420.98876953125, 138.69277954101562, 0.9341615438461304, 340.3092956542969, 215.12596130371094, 0.8273120522499084, 242.64466857910156, 236.35740661621094, 0.33336514234542847, 191.689208984375, 274.5740051269531, 0.9267236590385437, 246.89096069335938, 236.35740661621094, 0.3386761546134949, 183.19664001464844, 266.0814208984375, 0.9164185523986816, 259.62982177734375, 236.35740661621094, 0.4353731870651245, 221.41322326660156, 253.34255981445312, 0.7237583994865417], 'score': 3.0122275352478027, 'box': [180.82561961976742, 78.62149016140667, 314.0247145413133, 234.50012524589488], 'idx': 1}
# {'image_id': '00931.png', 'category_id': 1, 'keypoints': [375.3422546386719, 256.30767822265625, 0.8597800135612488, 379.5948791503906, 249.92874145507812, 0.7924415469169617, 364.710693359375, 252.0550537109375, 0.8273587226867676, 390.2264709472656, 232.91822814941406, 0.7784574031829834, 347.7001647949219, 241.42347717285156, 0.8275699019432068, 385.9738464355469, 245.6761016845703, 0.6390702724456787, 351.95281982421875, 269.0655517578125, 0.8348495960235596, 396.60540771484375, 258.4339904785156, 0.6631218791007996, 347.7001647949219, 298.8339538574219, 0.9058852195739746, 402.9843444824219, 264.81292724609375, 0.6506250500679016, 354.0791320800781, 324.3497314453125, 0.9552205204963684, 402.9843444824219, 286.0760803222656, 0.8111838698387146, 385.9738464355469, 309.4655456542969, 0.8204275965690613, 430.6264343261719, 290.3287048339844, 0.6521924138069153, 424.24749755859375, 322.2234191894531, 0.6627141833305359, 456.1422119140625, 290.3287048339844, 0.19481605291366577, 466.7737731933594, 334.9812927246094, 0.6567102670669556, 368.96331787109375, 213.78138732910156, 0.8604826331138611, 368.96331787109375, 249.92874145507812, 0.8685468435287476, 392.352783203125, 298.8339538574219, 0.8323190212249756, 490.1632385253906, 264.81292724609375, 0.2812541127204895, 479.5316467285156, 332.85498046875, 0.6746973395347595, 485.9106140136719, 260.560302734375, 0.20872052013874054, 479.5316467285156, 343.486572265625, 0.6587040424346924, 460.39483642578125, 266.9392395019531, 0.19681009650230408, 475.2790222167969, 337.10760498046875, 0.5722723603248596], 'score': 2.4446983337402344, 'box': [335.1549377441406, 196.85687255859375, 163.3009033203125, 155.04898071289062], 'idx': 7}
# {'image_id': '00931.png', 'category_id': 1, 'keypoints': [369.5674743652344, 257.5928649902344, 0.9013276696205139, 376.9481201171875, 253.16448974609375, 0.8370980620384216, 362.1868591308594, 253.16448974609375, 0.8601869344711304, 388.7571105957031, 238.4032440185547, 0.814813494682312, 348.9017333984375, 242.8316192626953, 0.8319422602653503, 384.3287353515625, 248.73611450195312, 0.8904407620429993, 351.85400390625, 270.87799072265625, 0.8190509080886841, 390.23321533203125, 256.1167297363281, 0.7872373461723328, 347.4256286621094, 300.40045166015625, 0.8926929831504822, 396.1377258300781, 260.54510498046875, 0.8783348798751831, 351.85400390625, 324.0184631347656, 0.9257003664970398, 406.4705810546875, 290.0675964355469, 0.7641984820365906, 390.23321533203125, 309.2572021484375, 0.7093024253845215, 428.6124572753906, 293.01983642578125, 0.5755663514137268, 418.27960205078125, 319.590087890625, 0.6515675783157349, 447.06402587890625, 290.8056640625, 0.143804132938385, 447.06402587890625, 329.1849060058594, 0.5133474469184875, 366.615234375, 211.83299255371094, 0.8362244963645935, 368.09136962890625, 253.16448974609375, 0.8975654244422913, 396.1377258300781, 298.9243469238281, 0.7844544053077698, 447.06402587890625, 293.7579040527344, 0.0819392055273056, 447.06402587890625, 320.3281555175781, 0.06796440482139587, 447.06402587890625, 284.9011535644531, 0.07465925812721252, 447.06402587890625, 335.0893859863281, 0.10792714357376099, 447.06402587890625, 314.42364501953125, 0.10347297787666321, 447.06402587890625, 332.13714599609375, 0.22738291323184967], 'score': 2.3518948554992676, 'box': [327.0092781470041, 197.31643060141536, 103.55614091208207, 150.6219086058948], 'idx': 6}
# 1 7
# --------
# Frame:  940
# View:  0
# Prev frame does not have 2 detections
# Removing by score in frame
# {'image_id': '00941.png', 'category_id': 1, 'keypoints': [431.29302978515625, 150.43360900878906, 0.9178284406661987, 444.1283264160156, 146.15518188476562, 0.9094521999359131, 427.0146179199219, 137.59832763671875, 0.9111643433570862, 456.9635925292969, 137.59832763671875, 0.5979307293891907, 414.1793518066406, 116.20620727539062, 0.8966090083122253, 452.6851806640625, 154.7120361328125, 0.8921924233436584, 379.9519348144531, 137.59832763671875, 0.9101927280426025, 452.6851806640625, 210.33157348632812, 0.8620379567146301, 384.2303466796875, 210.33157348632812, 0.8212661743164062, 461.2420349121094, 253.1158447265625, 0.9274324178695679, 418.457763671875, 188.939453125, 0.908675491809845, 371.39508056640625, 223.16685485839844, 0.9108211398124695, 320.053955078125, 218.888427734375, 0.8519116044044495, 388.5087890625, 270.22955322265625, 0.6037890911102295, 285.8265686035156, 295.90008544921875, 0.9202900528907776, 328.6108093261719, 270.22955322265625, 0.5528547167778015, 230.20703125, 257.3942565917969, 0.7644216418266296, 448.40673828125, 107.64935302734375, 0.9585034251213074, 422.7361755371094, 137.59832763671875, 0.903911292552948, 345.7245178222656, 214.61000061035156, 0.9100826382637024, 251.59915161132812, 240.2805633544922, 0.3042757511138916, 187.42276000976562, 274.5079650878906, 0.8498521447181702, 255.87757873535156, 240.2805633544922, 0.28621572256088257, 183.14434814453125, 265.95111083984375, 0.8641077280044556, 268.7128601074219, 236.00213623046875, 0.5260788202285767, 225.92860412597656, 248.83741760253906, 0.7109382152557373], 'score': 2.975590705871582, 'box': [179.56968861746773, 79.27312180885303, 320.06680915125105, 232.45889241784437], 'idx': 1}
# {'image_id': '00941.png', 'category_id': 1, 'keypoints': [379.8171081542969, 257.79083251953125, 0.822252631187439, 384.4541931152344, 250.83522033691406, 0.7689555287361145, 372.86151123046875, 255.4722900390625, 0.7325035333633423, 391.4097900390625, 236.92401123046875, 0.7209578156471252, 354.3132019042969, 248.51669311523438, 0.7853677272796631, 379.8171081542969, 241.5610809326172, 0.6277651786804199, 354.3132019042969, 274.0205993652344, 0.8361453413963318, 386.772705078125, 255.4722900390625, 0.5314600467681885, 356.6317443847656, 306.4801025390625, 0.9349865913391113, 400.6839294433594, 262.42791748046875, 0.6799831986427307, 368.22442626953125, 334.3025207519531, 0.974564790725708, 403.0024719238281, 280.9761962890625, 0.8929712772369385, 391.4097900390625, 308.7986145019531, 0.7765576839447021, 440.09906005859375, 285.6132507324219, 0.6080253720283508, 430.82489013671875, 322.7098388671875, 0.5818095803260803, 456.32879638671875, 283.29473876953125, 0.2571455240249634, 470.2400207519531, 331.9839782714844, 0.7514240741729736, 370.54296875, 216.0571746826172, 0.8456782698631287, 368.22442626953125, 250.83522033691406, 0.8004003167152405, 393.72833251953125, 292.5688781738281, 0.8677990436553955, 491.1068420410156, 269.3835144042969, 0.26941412687301636, 491.1068420410156, 329.66546630859375, 0.5635740756988525, 444.7361145019531, 271.7020568847656, 0.2600661516189575, 488.7882995605469, 338.9396057128906, 0.5866967439651489, 460.96588134765625, 269.3835144042969, 0.1879998743534088, 472.5585632324219, 334.3025207519531, 0.6919304132461548], 'score': 2.4153971672058105, 'box': [335.99676513671875, 200.08580017089844, 178.0635986328125, 159.4622344970703], 'idx': 8}
# {'image_id': '00941.png', 'category_id': 1, 'keypoints': [376.8670959472656, 263.0013427734375, 0.9226373434066772, 383.0794677734375, 255.23587036132812, 0.8104857206344604, 369.10162353515625, 258.3420715332031, 0.8442726135253906, 393.9511413574219, 238.15182495117188, 0.8401628136634827, 353.5706787109375, 247.47039794921875, 0.7517948150634766, 384.632568359375, 250.5765838623047, 0.7135542035102844, 355.1237487792969, 273.8730163574219, 0.8612252473831177, 390.8449401855469, 258.3420715332031, 0.7074174880981445, 355.1237487792969, 306.4880065917969, 0.8710178732872009, 400.16351318359375, 261.4482421875, 0.7588740587234497, 369.10162353515625, 334.4437255859375, 0.9702078104019165, 407.9289855957031, 287.8508605957031, 0.7073827981948853, 395.5042419433594, 312.70037841796875, 0.7550529837608337, 446.75634765625, 281.63848876953125, 0.5506072044372559, 431.22540283203125, 325.1251525878906, 0.4386434555053711, 425.0130310058594, 300.275634765625, 0.16288897395133972, 463.0638427734375, 333.66717529296875, 0.4126504063606262, 369.10162353515625, 219.5146942138672, 0.872411847114563, 372.2077941894531, 255.23587036132812, 0.8813509941101074, 397.05731201171875, 300.275634765625, 0.8228718042373657, 463.0638427734375, 274.6495666503906, 0.048475537449121475, 376.0905456542969, 377.15380859375, 0.04342665895819664, 463.0638427734375, 274.6495666503906, 0.034142788499593735, 463.0638427734375, 349.1981201171875, 0.08991841971874237, 423.4599304199219, 308.0411071777344, 0.16347229480743408, 463.0638427734375, 330.56097412109375, 0.2587023377418518], 'score': 2.3496227264404297, 'box': [329.7815994837125, 201.05892295540343, 133.19095271437396, 158.8535002544412], 'idx': 6}
# 1 8
# --------
# Frame:  974
# View:  0
# Prev idx:  1
# Candidate idx  [1, 9, 2]
# Prev idx:  9
# Candidate idx  [1, 9, 2]
# [8.006377269251225, 48.16829488798976, 54.51583071664358]
# [55.101365991032274, 1.6227483031077263, 7.748967304539222]
# [0, 1]
# 1 9
# --------
# Frame:  975
# View:  0
# Prev idx:  1
# Candidate idx  [1, 9, 2]
# Prev idx:  9
# Candidate idx  [1, 9, 2]
# [0.0, 55.56358909062468, 60.17843078248776]
# [55.56358909062468, 0.0, 7.2429448168438215]
# [0, 1]
# 1 9
# --------
# Frame:  976
# View:  0
# Prev idx:  1
# Candidate idx  [1, 9, 2]
# Prev idx:  9
# Candidate idx  [1, 9, 2]
# [3.0063164262817454, 54.95812224845091, 59.770569288386746]
# [54.266977628931784, 2.1256758623207226, 6.7882562559575605]
# [0, 1]
# 1 9
# --------
# Frame:  977
# View:  0
# Prev idx:  1
# Candidate idx  [1, 9, 2]
# Prev idx:  9
# Candidate idx  [1, 9, 2]
# [2.677511357726195, 53.84664149353137, 60.35224227091441]
# [54.35965825292544, 0.7978635225922633, 8.941849680665213]
# [0, 1]
# 1 9
# --------
# Frame:  980
# View:  0
# Prev frame does not have 2 detections
# Removing by score in frame
# {'image_id': '00981.png', 'category_id': 1, 'keypoints': [416.7523193359375, 152.48080444335938, 0.9662994146347046, 425.22271728515625, 144.01040649414062, 0.9224379658699036, 412.5171203613281, 139.7751922607422, 0.9368535876274109, 437.9283447265625, 135.5399932861328, 0.6523869633674622, 399.8114929199219, 122.83438873291016, 0.9257270097732544, 433.6931457519531, 152.48080444335938, 0.9415821433067322, 361.6946716308594, 135.5399932861328, 0.9204455018043518, 446.39874267578125, 203.30323791503906, 0.9041662812232971, 319.3426513671875, 182.12722778320312, 0.8686653971672058, 459.1043395996094, 254.1256866455078, 0.8945021629333496, 327.81304931640625, 232.9496612548828, 0.8783988356590271, 374.4002990722656, 220.24404907226562, 0.8599171042442322, 327.81304931640625, 211.77365112304688, 0.8728999495506287, 382.8706970214844, 262.5960998535156, 0.5812378525733948, 285.4610290527344, 292.2425231933594, 0.8752792477607727, 289.69622802734375, 241.42007446289062, 0.43210524320602417, 226.16818237304688, 258.3608703613281, 0.7987560629844666, 433.6931457519531, 110.12877655029297, 0.938347339630127, 408.28192138671875, 135.5399932861328, 0.9374608993530273, 353.2242736816406, 211.77365112304688, 0.9302272200584412, 251.5793914794922, 237.18487548828125, 0.3331337571144104, 188.0513458251953, 275.30169677734375, 0.9173765182495117, 255.81460571289062, 232.9496612548828, 0.3591376543045044, 183.81614685058594, 266.831298828125, 0.8479843735694885, 276.9906311035156, 241.42007446289062, 0.6093413829803467, 226.16818237304688, 245.6552734375, 0.7310479879379272], 'score': 3.0017189979553223, 'box': [174.80824583444064, 81.83034767274663, 327.2905315011293, 229.70715589390224], 'idx': 1}
# {'image_id': '00981.png', 'category_id': 1, 'keypoints': [377.9188232421875, 239.7877960205078, 0.9303491115570068, 384.02410888671875, 232.1561737060547, 0.8798497915267944, 368.7608642578125, 235.2088165283203, 0.9549390077590942, 390.1294250488281, 224.5245361328125, 0.6979984641075134, 351.9712829589844, 230.62985229492188, 0.8603597283363342, 380.9714660644531, 242.8404541015625, 0.6759548783302307, 356.5502624511719, 259.6300354003906, 0.8261194825172424, 387.0767822265625, 258.10369873046875, 0.8295676708221436, 358.0765686035156, 294.73553466796875, 0.8939185738563538, 400.8136901855469, 261.1563720703125, 0.8598111867904663, 379.44512939453125, 291.6828918457031, 0.8692351579666138, 390.1294250488281, 280.99859619140625, 0.6162594556808472, 373.33984375, 303.89349365234375, 0.5580381155014038, 409.9716491699219, 284.0512390136719, 0.5248956680297852, 409.9716491699219, 314.5777587890625, 0.6854309439659119, 422.1822509765625, 291.6828918457031, 0.36221805214881897, 446.6034851074219, 326.7883605957031, 0.44331154227256775, 368.7608642578125, 198.57699584960938, 0.8632043600082397, 368.7608642578125, 242.8404541015625, 0.8288573026657104, 380.9714660644531, 290.15655517578125, 0.6171243190765381, 446.6034851074219, 282.5249328613281, 0.2908609211444855, 448.8929748535156, 326.02520751953125, 0.1395992487668991, 446.6034851074219, 282.5249328613281, 0.24659773707389832, 448.8929748535156, 329.0778503417969, 0.1936357170343399, 422.1822509765625, 303.89349365234375, 0.20046880841255188, 448.8929748535156, 329.0778503417969, 0.3148799538612366], 'score': 2.334498882293701, 'box': [333.5746593572491, 183.86068718490515, 90.8838122755975, 156.1243009262015], 'idx': 9}
# {'image_id': '00981.png', 'category_id': 1, 'keypoints': [376.45367431640625, 241.31845092773438, 0.8982569575309753, 383.59942626953125, 234.1726837158203, 0.9076305031776428, 369.30792236328125, 234.1726837158203, 0.8921337127685547, 390.7452087402344, 227.02691650390625, 0.820424497127533, 352.63446044921875, 231.79075622558594, 0.9583681225776672, 383.59942626953125, 243.7003631591797, 0.823133647441864, 357.3983154296875, 257.99188232421875, 0.8364470601081848, 388.36328125, 262.7557373046875, 0.9641242027282715, 359.78021240234375, 293.720703125, 0.9423027634620667, 405.0367126464844, 262.7557373046875, 0.962096095085144, 378.8356018066406, 293.720703125, 0.9657588005065918, 395.509033203125, 291.3387756347656, 0.8345103859901428, 378.8356018066406, 308.0122375488281, 0.808330237865448, 431.23785400390625, 291.3387756347656, 0.6800193190574646, 414.5644226074219, 315.1579895019531, 0.6521661877632141, 476.4943542480469, 303.2483825683594, 0.4384889006614685, 466.9666748046875, 331.8314208984375, 0.795738160610199, 369.30792236328125, 198.44386291503906, 0.9416475892066956, 366.9259948730469, 243.7003631591797, 0.8743091225624084, 383.59942626953125, 300.866455078125, 0.7787245512008667, 495.54974365234375, 262.7557373046875, 0.30369532108306885, 493.1678161621094, 327.0675964355469, 0.5282773375511169, 488.4039611816406, 265.1376647949219, 0.25141245126724243, 493.1678161621094, 338.9772033691406, 0.5557645559310913, 483.64013671875, 317.5399169921875, 0.22692617774009705, 478.87628173828125, 336.59527587890625, 0.708663284778595], 'score': 2.546863555908203, 'box': [330.9400444014998, 185.93426380689795, 193.98224787669233, 160.1234448083763], 'idx': 2}
# 1 2
# --------
# Frame:  981
# View:  0
# Prev idx:  1
# Candidate idx  [1, 9, 2]
# Prev idx:  2
# Candidate idx  [1, 9, 2]
# [0.0, 55.4655938381568, 61.03044684995444]
# [61.03044684995444, 6.994394998519849, 0.0]
# [0, 2]
# 1 2
# --------
# Frame:  989
# View:  0
# Prev idx:  1
# Candidate idx  [1, 2, 9]
# Prev idx:  2
# Candidate idx  [1, 2, 9]
# [0.7109018094264544, 60.17220736180361, 56.49826334655667]
# [59.54500841072355, 2.1756576673151593, 3.7991579194099474]
# [0, 1]
# 1 2
# --------
# Frame:  996
# View:  0
# Prev idx:  1
# Candidate idx  [1, 2, 9]
# Prev idx:  2
# Candidate idx  [1, 2, 9]
# [1.0225652383688169, 58.66095533107336, 56.443450486526274]
# [58.94279286876703, 3.375022267874999, 5.61886419632878]
# [0, 1]
# 1 2
# --------
# Frame:  272
# View:  1
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [2.08554593874858, 64.37175252813941, 20.86174666852905]
# [62.6902479108614, 11.274378023325252, 67.03130694426214]
# [0, 1]
# 1 2
# --------
# Frame:  273
# View:  1
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [0.0, 64.63613218613543, 20.192081121775583]
# [64.63613218613543, 0.0, 67.26655872299885]
# [0, 1]
# 1 2
# --------
# Frame:  443
# View:  1
# Prev idx:  2
# Candidate idx  [2, 1, 4]
# Prev idx:  1
# Candidate idx  [2, 1, 4]
# [6.940652401592487, 53.27232157033033, 58.656371412703244]
# [55.02612625697675, 8.846391571637911, 1.711366558686281]
# [0, 2]
# 2 4
# --------
# Frame:  500
# View:  1
# Prev idx:  2
# Candidate idx  [2, 1, 5]
# Prev idx:  1
# Candidate idx  [2, 1, 5]
# [9.009517508344008, 64.76299746611562, 58.916854761349846]
# [62.415373723858444, 1.6511226495107014, 14.134175709711435]
# [0, 1]
# 2 1
# --------
# Frame:  501
# View:  1
# Prev idx:  2
# Candidate idx  [2, 1, 5]
# Prev idx:  1
# Candidate idx  [2, 1, 5]
# [0.0, 62.58407417283608, 58.2267876770825]
# [62.58407417283608, 0.0, 13.962430780801254]
# [0, 1]
# 2 1
# --------
# Frame:  506
# View:  1
# Prev idx:  2
# Candidate idx  [2, 1, 5]
# Prev idx:  1
# Candidate idx  [2, 1, 5]
# [8.849996430966526, 66.78984810497899, 65.66322191967032]
# [61.52814125816505, 1.3563865369711168, 9.620835598271627]
# [0, 1]
# 2 1
# --------
# Frame:  507
# View:  1
# Prev idx:  2
# Candidate idx  [2, 1, 5]
# Prev idx:  1
# Candidate idx  [2, 1, 5]
# [0.0, 61.698652344182705, 62.149312945249946]
# [61.698652344182705, 0.0, 9.817405899174702]
# [0, 1]
# 2 1
# --------
# Frame:  516
# View:  1
# Prev idx:  2
# Candidate idx  [2, 5, 1]
# Prev idx:  5
# Candidate idx  [2, 5, 1]
# [3.0889649867342834, 49.1267031753579, 62.484811421722554]
# [62.0598515863411, 16.63205915288283, 16.90418067861062]
# [0, 1]
# 2 5
# --------
# Frame:  517
# View:  1
# Prev idx:  2
# Candidate idx  [2, 5, 1]
# Prev idx:  5
# Candidate idx  [2, 5, 1]
# [2.7125069200992584, 53.686637026186176, 60.05372943222905]
# [48.950260872355635, 8.50673632715375, 15.44491802270596]
# [0, 1]
# 2 5
# --------
# Frame:  526
# View:  1
# Prev idx:  2
# Candidate idx  [2, 5, 1]
# Prev idx:  5
# Candidate idx  [2, 5, 1]
# [2.9771157946342077, 61.68563784042803, 65.20625711514208]
# [56.088877685559105, 10.050116665422534, 13.968063335722455]
# [0, 1]
# 2 5
# --------
# Frame:  527
# View:  1
# Prev idx:  2
# Candidate idx  [2, 5, 1]
# Prev idx:  5
# Candidate idx  [2, 5, 1]
# [3.2582656529326086, 59.690941696222396, 63.88390052791398]
# [58.660860927942664, 3.110893491655588, 5.0336499856068535]
# [0, 1]
# 2 5
# --------
# Frame:  540
# View:  1
# Prev idx:  2
# Candidate idx  [2, 1, 5]
# Prev idx:  1
# Candidate idx  [2, 1, 5]
# [5.527968673823545, 64.81425875317879, 58.00387339358433]
# [63.43901290453206, 2.033583947481253, 10.478585299199972]
# [0, 1]
# 2 1
# --------
# Frame:  708
# View:  1
# Prev idx:  2
# Candidate idx  [2, 1, 5]
# Prev idx:  1
# Candidate idx  [2, 1, 5]
# [7.530870177257711, 58.20806868584492, 65.776002996434]
# [55.122122713555704, 7.8575763789316015, 14.056544198726233]
# [0, 1]
# 2 1
# --------
# Frame:  796
# View:  1
# Prev idx:  2
# Candidate idx  [2, 5, 6]
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# [15.852190012733141, 67.63870146393012, 29.024080966706745]
# [57.2511225778323, 2.421913330180523, 51.662242385618484]
# [0, 1]
# 2 5
# --------
# Frame:  797
# View:  1
# Prev idx:  2
# Candidate idx  [2, 5, 6]
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# [21.112611640913364, 56.86675729984656, 20.968255476106723]
# [74.62458114020335, 1.5511753196135545, 51.542450044387714]
# [2, 1]
# 6 5
# Removing by score in frame
# {'image_id': '00798.png', 'category_id': 1, 'keypoints': [640.776611328125, 161.05514526367188, 0.9584012031555176, 652.9221801757812, 142.8368682861328, 0.9666764736175537, 622.558349609375, 142.8368682861328, 0.9848638772964478, 665.0676879882812, 136.7641143798828, 0.8555091619491577, 598.267333984375, 130.6913604736328, 0.9611473679542542, 689.3587036132812, 197.49168395996094, 0.872672975063324, 561.830810546875, 179.27340698242188, 0.9399814009666443, 695.4314575195312, 306.80126953125, 0.8702013492584229, 519.321533203125, 246.07373046875, 0.7327787280082703, 713.6497192382812, 416.11090087890625, 0.7639618515968323, 513.248779296875, 288.5830078125, 0.6054322123527527, 628.631103515625, 355.3833312988281, 0.7128044366836548, 549.685302734375, 337.1650695800781, 0.6945151090621948, 634.703857421875, 434.32916259765625, 0.5073991417884827, 410.0119323730469, 403.9653625488281, 0.457542359828949, 385.72088623046875, 391.8198547363281, 0.30008456110954285, 604.340087890625, 488.98394775390625, 0.5909847617149353, 634.703857421875, 88.18207550048828, 0.9060990810394287, 628.631103515625, 173.20065307617188, 0.9406466484069824, 592.194580078125, 337.1650695800781, 0.8505804538726807, 331.06610107421875, 397.8926086425781, 0.43519696593284607, 331.06610107421875, 397.8926086425781, 0.7043905854225159, 337.13885498046875, 403.9653625488281, 0.4875267744064331, 324.99334716796875, 391.8198547363281, 0.6703330874443054, 634.703857421875, 470.76568603515625, 0.4317269027233124, 367.50262451171875, 385.7471008300781, 0.5923786163330078], 'score': 2.930722236633301, 'box': [344.13116595660074, 61.982183622466806, 420.2035842397896, 409.6954217663109], 'idx': 2}
# {'image_id': '00798.png', 'category_id': 1, 'keypoints': [556.7708740234375, 310.3570861816406, 0.9622898101806641, 562.2903442382812, 296.5583801269531, 0.9328557252883911, 540.2124633789062, 302.0778503417969, 0.9624415040016174, 567.809814453125, 291.0389099121094, 0.5651838183403015, 504.3358459472656, 299.318115234375, 0.9170261025428772, 567.809814453125, 340.7142028808594, 0.8768091201782227, 507.0955810546875, 351.7531433105469, 0.9450880885124207, 589.8877563476562, 384.8700256347656, 0.9327864646911621, 523.6539916992188, 404.1882019042969, 0.8983829021453857, 609.2059326171875, 415.2271423339844, 0.9270967245101929, 576.0890502929688, 426.26611328125, 0.942768931388855, 559.5306396484375, 426.26611328125, 0.7659691572189331, 507.0955810546875, 431.78558349609375, 0.8173341751098633, 611.9656372070312, 437.3050537109375, 0.5324149131774902, 531.9332275390625, 451.103759765625, 0.8736781477928162, 620.244873046875, 470.42193603515625, 0.45127296447753906, 576.0890502929688, 486.9803771972656, 0.7032614350318909, 534.6929931640625, 246.88307189941406, 0.9497331976890564, 531.9332275390625, 329.67523193359375, 0.9874808192253113, 534.6929931640625, 426.26611328125, 0.8028557896614075, 661.6409912109375, 481.46087646484375, 0.24986663460731506, 600.9266967773438, 481.46087646484375, 0.4522036015987396, 669.920166015625, 506.29852294921875, 0.3429112732410431, 592.6475219726562, 495.25958251953125, 0.5182843208312988, 634.0435791015625, 509.05828857421875, 0.29393482208251953, 600.9266967773438, 506.29852294921875, 0.6867781281471252], 'score': 2.8627562522888184, 'box': [468.80574120360814, 233.7109689102856, 180.27623467673038, 282.6294248393734], 'idx': 5}
# {'image_id': '00798.png', 'category_id': 1, 'keypoints': [636.8749389648438, 159.60020446777344, 0.9242247939109802, 652.7627563476562, 147.68429565429688, 0.9079359769821167, 624.958984375, 143.7123260498047, 0.9408854842185974, 660.7067260742188, 135.76840209960938, 0.8202594518661499, 597.1552124023438, 127.824462890625, 0.9350182414054871, 688.510498046875, 195.347900390625, 0.8666245341300964, 565.3795166015625, 179.4600372314453, 0.8671838641166687, 692.482421875, 318.4788818359375, 0.883486807346344, 529.6317749023438, 254.92739868164062, 0.7955262064933777, 708.3703002929688, 417.7780456542969, 0.9371100068092346, 537.5757446289062, 338.3387145996094, 0.61278235912323, 632.9029541015625, 362.1705017089844, 0.7091482877731323, 561.4075317382812, 346.2826232910156, 0.7343053221702576, 613.0430908203125, 445.5818176269531, 0.489462286233902, 549.4916381835938, 441.6098327636719, 0.5957716107368469, 636.8749389648438, 409.8341064453125, 0.2766248881816864, 569.3514404296875, 421.75, 0.24549952149391174, 636.8749389648438, 92.07676696777344, 0.8930826783180237, 628.9309692382812, 167.54412841796875, 0.9348364472389221, 597.1552124023438, 346.2826232910156, 0.8004709482192993, 644.81884765625, 429.6939392089844, 0.36389344930648804, 573.3234252929688, 421.75, 0.008429344743490219, 648.7908325195312, 425.72198486328125, 0.4230140447616577, 497.8560485839844, 425.72198486328125, 0.010967223905026913, 640.8468627929688, 397.918212890625, 0.19467605650424957, 577.29541015625, 425.72198486328125, 0.02764700911939144], 'score': 2.3043384552001953, 'box': [518.3708391587222, 64.9032943725586, 264.5360804716182, 407.21636962890625], 'idx': 6}
# 2 5
# --------
# Frame:  799
# View:  1
# Prev idx:  2
# Candidate idx  [2, 5, 7, 6]
# Prev idx:  5
# Candidate idx  [2, 5, 7, 6]
# [15.343241670765938, 75.39423706974739, 67.79384622159294, 37.33712617255365]
# [69.63837647839235, 0.9192670553158491, 8.802803865132423, 54.08788210693269]
# [0, 1]
# 2 5
# --------
# Frame:  800
# View:  1
# Prev idx:  2
# Candidate idx  [2, 5, 6]
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# [3.904036237834356, 71.66114226919719, 23.229511096691475]
# [70.7732527557856, 2.930837178459534, 54.39462947253234]
# [0, 1]
# 2 5
# --------
# Frame:  801
# View:  1
# Prev idx:  2
# Candidate idx  [2, 5, 6]
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# [0.0, 72.21038550673387, 21.626283194583195]
# [72.21038550673387, 0.0, 55.11318215097372]
# [0, 1]
# 2 5
# --------
# Frame:  802
# View:  1
# Prev idx:  2
# Candidate idx  [2, 5, 6, 1]
# Prev idx:  5
# Candidate idx  [2, 5, 6, 1]
# [4.425179499846238, 72.62535849251809, 30.65559882727953, 68.76878658204507]
# [71.82863924977107, 2.445116939070897, 60.95045888538544, 7.16931529648793]
# [0, 1]
# 2 5
# --------
# Frame:  803
# View:  1
# Prev idx:  2
# Candidate idx  [2, 5, 6]
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# [18.36039761855052, 73.67153092798515, 30.658420405708828]
# [78.82463890505143, 2.749660923694953, 62.017096382685196]
# [0, 1]
# 2 5
# Removing by score in frame
# {'image_id': '00804.png', 'category_id': 1, 'keypoints': [665.6771240234375, 182.64283752441406, 0.95856773853302, 677.9862060546875, 170.33375549316406, 0.9275001883506775, 653.3680419921875, 164.17921447753906, 0.9408196210861206, 696.4498291015625, 164.17921447753906, 0.8692088723182678, 634.9044189453125, 145.71559143066406, 0.9157267808914185, 721.0679321289062, 207.26100158691406, 0.8598164916038513, 585.6680908203125, 194.95191955566406, 0.923324704170227, 714.9133911132812, 318.042724609375, 0.8067644834518433, 542.5863037109375, 274.9609375, 0.7085718512535095, 721.0679321289062, 416.5153503417969, 0.6318132877349854, 561.0499267578125, 324.197265625, 0.5887819528579712, 659.5225830078125, 354.969970703125, 0.7675549983978271, 591.8226318359375, 348.8154296875, 0.6368097066879272, 653.3680419921875, 410.3608093261719, 0.5090895891189575, 591.8226318359375, 434.9789733886719, 0.32010602951049805, 690.2952880859375, 422.6698913574219, 0.26744067668914795, 388.7228088378906, 398.0517272949219, 0.42097008228302, 677.9862060546875, 108.7883529663086, 0.9397720098495483, 659.5225830078125, 182.64283752441406, 0.8895614743232727, 628.7498779296875, 342.660888671875, 0.8118346333503723, 351.7955627441406, 398.0517272949219, 0.2944413125514984, 339.4864807128906, 398.0517272949219, 0.7935051321983337, 351.7955627441406, 404.2062683105469, 0.32449302077293396, 333.3319396972656, 398.0517272949219, 0.8077141642570496, 671.8316650390625, 447.2880554199219, 0.22986793518066406, 370.2591857910156, 398.0517272949219, 0.5106774568557739], 'score': 2.7166013717651367, 'box': [339.8853802979787, 79.40756347598017, 425.5351673088021, 383.1878064694545], 'idx': 2}
# {'image_id': '00804.png', 'category_id': 1, 'keypoints': [523.9373779296875, 314.2795715332031, 0.9715195894241333, 534.9673461914062, 300.49212646484375, 0.9086206555366516, 510.14990234375, 306.0071105957031, 0.9322474002838135, 557.0272216796875, 294.9771423339844, 0.8592451810836792, 493.6049499511719, 303.2496032714844, 0.9373770952224731, 568.0571899414062, 341.8544921875, 0.9331939220428467, 501.87744140625, 352.88446044921875, 0.9197156429290771, 587.359619140625, 385.9743347167969, 0.9352903962135315, 518.42236328125, 402.519287109375, 0.8885437250137329, 606.6620483398438, 416.3067321777344, 0.9459711909294128, 573.5722045898438, 424.5792236328125, 0.9645852446556091, 562.542236328125, 427.3367004394531, 0.8462930917739868, 507.39239501953125, 432.8516845703125, 0.7820693850517273, 606.6620483398438, 441.1241455078125, 0.49082091450691223, 532.2098388671875, 452.15411376953125, 0.8331097364425659, 634.2369995117188, 474.21405029296875, 0.3672460615634918, 587.359619140625, 490.7590026855469, 0.5609889030456543, 518.42236328125, 253.61477661132812, 0.9099809527397156, 529.4523315429688, 328.0670166015625, 0.9168935418128967, 537.7247924804688, 424.5792236328125, 0.8172679543495178, 675.599365234375, 496.2739562988281, 0.359544038772583, 648.0244140625, 488.0014953613281, 0.247248113155365, 675.599365234375, 501.7889404296875, 0.4402313530445099, 639.751953125, 507.3039245605469, 0.3764558732509613, 645.2669677734375, 512.8189086914062, 0.2665562629699707, 634.2369995117188, 512.8189086914062, 0.49186059832572937], 'score': 2.820138931274414, 'box': [469.7220660981502, 234.786982740469, 178.50463473364744, 282.3150563393472], 'idx': 5}
# {'image_id': '00804.png', 'category_id': 1, 'keypoints': [665.5370483398438, 184.4005584716797, 0.9261012673377991, 682.93212890625, 167.00550842285156, 0.9436453580856323, 655.0999755859375, 163.5264892578125, 0.9824510812759399, 696.84814453125, 160.04747009277344, 0.8407753109931946, 634.2258911132812, 142.65240478515625, 0.9219518303871155, 717.7222290039062, 212.232666015625, 0.7997252941131592, 588.998779296875, 187.87957763671875, 0.8950942158699036, 710.7642211914062, 316.6030578613281, 0.7964383959770203, 540.2926025390625, 278.33392333984375, 0.6823739409446716, 707.2852172851562, 410.5364074707031, 0.8372592329978943, 592.477783203125, 313.1240539550781, 0.8251508474349976, 658.5790405273438, 389.6623229980469, 0.6404138803482056, 585.5197143554688, 379.22528076171875, 0.7098137736320496, 641.1839599609375, 469.67962646484375, 0.22937417030334473, 585.5197143554688, 469.67962646484375, 0.40204983949661255, 710.7642211914062, 417.4944152832031, 0.6415301561355591, 707.2852172851562, 424.45245361328125, 0.19586491584777832, 672.4950561523438, 121.77833557128906, 0.7752776741981506, 662.0580444335938, 184.4005584716797, 0.9379255175590515, 623.7888793945312, 375.74627685546875, 0.7604285478591919, 755.9913940429688, 459.2425842285156, 0.513762891292572, 749.0333251953125, 448.8055419921875, 0.32409241795539856, 752.5123291015625, 448.8055419921875, 0.45091694593429565, 745.5543212890625, 452.2845458984375, 0.3210754096508026, 707.2852172851562, 420.97344970703125, 0.5212280750274658, 710.7642211914062, 427.93145751953125, 0.22326990962028503], 'score': 2.7707526683807373, 'box': [530.6071532317432, 80.53503897086497, 234.30127238793796, 358.35048180822514], 'idx': 6}
# 5 6
# --------
# Frame:  804
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [81.97408433946279, 3.1091077014421806, 62.91642479522106]
# [43.533422484993935, 63.85408216103529, 8.372666898064125]
# [1, 2]
# 5 6
# --------
# Frame:  805
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [71.46497516888074, 1.6017212737829258, 64.44523058812588]
# [26.65276045466845, 65.52304997161413, 5.104504719567605]
# [1, 2]
# 5 6
# --------
# Frame:  806
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [79.31136777595832, 1.261217326307908, 65.0959408143774]
# [37.27245779068042, 65.15315213780373, 4.440451829861372]
# [1, 2]
# 5 6
# --------
# Frame:  807
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [79.83900299458168, 0.0, 65.35492684844976]
# [39.05711988531626, 65.35492684844976, 0.0]
# [1, 2]
# 5 6
# --------
# Frame:  808
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [75.44553660181089, 2.394341006875038, 64.13449803625161]
# [34.60190480068708, 66.35804643749427, 6.525429671391462]
# [1, 2]
# 5 6
# --------
# Frame:  809
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [68.51504945143675, 0.8493601683622751, 63.993950600998524]
# [20.06423039638843, 65.56314518340888, 4.600394538197762]
# [1, 2]
# 5 6
# --------
# Frame:  810
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [40.20937593701558, 0.9055849241140561, 63.89436799564805]
# [37.407223771588924, 64.33423455078632, 1.9250708099168081]
# [1, 2]
# 5 6
# --------
# Frame:  811
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [62.08290999478255, 0.746371641373023, 64.92445446971135]
# [17.81524349223727, 64.11833637351027, 3.742796539591673]
# [1, 2]
# 5 6
# --------
# Frame:  812
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [60.23413564283879, 1.058908353631313, 64.66653079654162]
# [16.699220318633778, 65.33224853300132, 3.260895790388951]
# [1, 2]
# 5 6
# --------
# Frame:  813
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [60.25223634506647, 0.0, 64.76183516761431]
# [16.954805875053772, 64.76183516761431, 0.0]
# [1, 2]
# 5 6
# --------
# Frame:  814
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [57.77624988670532, 2.1046042851148505, 66.30624744926507]
# [11.144657203211235, 63.655146796160786, 5.177219603306208]
# [1, 2]
# 5 6
# --------
# Frame:  815
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [63.787218481493305, 1.4478712882368991, 65.4759438267121]
# [13.556207600694437, 65.16290126511684, 4.664294295395032]
# [1, 2]
# 5 6
# --------
# Frame:  816
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [62.58206939754578, 1.3239287970921931, 64.56127700496178]
# [15.738641916177212, 64.95598176331856, 1.6281229952971141]
# [1, 2]
# 5 6
# --------
# Frame:  817
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [57.07036820760904, 2.524271629273127, 63.622382121017345]
# [11.544676622137045, 65.12017964963347, 5.50724503168693]
# [1, 2]
# 5 6
# --------
# Frame:  818
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [63.818486403482844, 1.2138069614959068, 63.117071026697374]
# [28.91704477255161, 63.846852713670486, 2.6860292683809233]
# [1, 2]
# 5 6
# --------
# Frame:  819
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [63.19799043314579, 0.0, 62.41670147654338]
# [29.878970863727425, 62.41670147654338, 0.0]
# [1, 2]
# 5 6
# --------
# Frame:  820
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [75.9199317460641, 1.9589384424571807, 62.80552167273485]
# [38.16903374325006, 61.597479172337515, 2.8083640852799783]
# [1, 2]
# 5 6
# --------
# Frame:  821
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [69.57092119056063, 0.839196557417894, 61.16646053804419]
# [24.704402790428738, 61.777842338364096, 3.7104508019028564]
# [1, 2]
# 5 6
# --------
# Frame:  822
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [69.01299619741546, 1.7056732550263405, 62.54248671567975]
# [24.035965466346497, 61.439310329942366, 4.774355123440425]
# [1, 2]
# 5 6
# --------
# Frame:  823
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [71.14953694960627, 0.4944343585998584, 60.77308646350717]
# [27.49650553117196, 62.86506507612574, 4.956273888548215]
# [1, 2]
# 5 6
# --------
# Frame:  824
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [68.60425147844049, 2.576347691986041, 60.087569902436094]
# [25.904290297856697, 60.7570707316582, 3.516519930500251]
# [1, 2]
# 5 6
# --------
# Frame:  825
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [68.6427331822805, 0.0, 60.215011547773315]
# [24.01578093606692, 60.215011547773315, 0.0]
# [1, 2]
# 5 6
# --------
# Frame:  826
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [67.92269073464932, 3.1640496757359076, 60.457848533796955]
# [23.686938599134102, 60.0019778096332, 1.7719554845721295]
# [1, 2]
# 5 6
# --------
# Frame:  827
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [54.5119978611668, 1.689778021703928, 59.77088944719006]
# [16.675368683555952, 59.757721140121035, 1.286441571246355]
# [1, 2]
# 5 6
# --------
# Frame:  828
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [67.14554127334402, 1.5480644488945985, 57.95957409848388]
# [24.055097856200657, 60.07393027125643, 1.8321041751366396]
# [1, 2]
# 5 6
# --------
# Frame:  829
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [64.34355651997986, 0.6770544585127097, 58.43723691226198]
# [21.827601150824474, 58.54955955871787, 1.585479541657827]
# [1, 2]
# 5 6
# --------
# Frame:  830
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [67.90112419149432, 1.1339191975883949, 58.43741134506388]
# [22.006382716962925, 58.088867945071215, 1.1154253792304258]
# [1, 2]
# 5 6
# --------
# Frame:  831
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [67.88521010266282, 0.0, 58.28774998881496]
# [21.976107228069733, 58.28774998881496, 0.0]
# [1, 2]
# 5 6
# --------
# Frame:  832
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [66.49719241844156, 1.8735289154335475, 58.75645603592961]
# [18.553464390337467, 59.110432446576084, 5.422226056265525]
# [1, 2]
# 5 6
# --------
# Frame:  833
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [68.91310275326937, 0.6655524944265684, 60.34623066603373]
# [24.703347106774647, 59.789238244868244, 1.3946171993246446]
# [1, 2]
# 5 6
# --------
# Frame:  834
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [68.0836871873874, 0.7688445809942025, 60.08367858674281]
# [25.99428395086374, 60.83970160648609, 3.3578240011747065]
# [1, 2]
# 5 6
# --------
# Frame:  835
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [68.56337045801756, 0.9673736418286959, 61.63836630777671]
# [24.175036633626007, 60.3810256421566, 1.9827457746634116]
# [1, 2]
# 5 6
# --------
# Frame:  836
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [68.7198965469232, 1.9006502672265737, 60.80477430766974]
# [24.211372736172798, 61.71562992896025, 2.184674295095297]
# [1, 2]
# 5 6
# --------
# Frame:  837
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [68.62926250677079, 0.0, 60.866199212769665]
# [23.530374536147484, 60.866199212769665, 0.0]
# [1, 2]
# 5 6
# --------
# Frame:  838
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [74.77493248211267, 1.0644291022267096, 60.59834958670231]
# [35.52128258271095, 61.155556520590416, 1.5773179832941446]
# [1, 2]
# 5 6
# --------
# Frame:  839
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [68.68834243886747, 0.8336627724078985, 61.9876439582843]
# [24.397210303216408, 61.425100665826065, 2.0745592751564126]
# [1, 2]
# 5 6
# --------
# Frame:  840
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [70.13691192750747, 1.1828586004483395, 64.64651559694455]
# [23.014522521541668, 63.021566946154984, 3.740084684621065]
# [1, 2]
# 5 6
# --------
# Frame:  841
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [70.04228839526574, 1.440884652428138, 64.14539617834947]
# [27.47128631785894, 66.04543911283596, 2.6445487827444687]
# [1, 2]
# 5 6
# --------
# Frame:  842
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [65.52436564442439, 1.4027070206327317, 63.41880110966471]
# [26.195191196142098, 65.65909672337465, 2.363311701000501]
# [1, 2]
# 5 6
# --------
# Frame:  843
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [65.76411917213446, 0.0, 64.03050388825628]
# [24.599040777159807, 64.03050388825628, 0.0]
# [1, 2]
# 5 6
# --------
# Frame:  844
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [71.09198551548597, 1.681348792444437, 64.81437124178196]
# [24.168394532627783, 63.65246658590742, 1.2192314631090715]
# [1, 2]
# 5 6
# --------
# Frame:  845
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [75.69477801636243, 1.5878049998711317, 67.75597016121715]
# [37.03691530609742, 65.14437539264178, 3.973441651711861]
# [1, 2]
# 5 6
# --------
# Frame:  846
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [68.77268228813624, 1.2988030793957221, 68.04440798046879]
# [16.378707421800264, 67.99684244556687, 1.8352883698848577]
# [1, 2]
# 5 6
# --------
# Frame:  847
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [74.7724784029982, 0.8573285816953733, 67.05990090608023]
# [39.869168458745264, 67.37056948082187, 1.5090949869213195]
# [1, 2]
# 5 6
# --------
# Frame:  848
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [74.04610516589422, 0.9650676009746698, 63.92992308344214]
# [40.59536147924761, 66.77501413880441, 3.229048854504258]
# [1, 2]
# 5 6
# --------
# Frame:  849
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [74.66747538936444, 0.0, 63.86201205419806]
# [38.01365331837382, 63.86201205419806, 0.0]
# [1, 2]
# 5 6
# --------
# Frame:  850
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [76.21002391477425, 1.1586285907870684, 66.9061793673497]
# [36.39532523650007, 64.23494434862947, 4.058949971714845]
# [1, 2]
# 5 6
# --------
# Frame:  851
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [74.42578662645359, 1.026624168532017, 66.07539120870523]
# [40.22545800682826, 66.80014121303192, 1.6569042882094016]
# [1, 2]
# 5 6
# --------
# Frame:  852
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [75.50786656217697, 2.404785400399795, 65.83761396249517]
# [39.34976750497635, 65.13019092419209, 0.5760249582429727]
# [1, 2]
# 5 6
# --------
# Frame:  853
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [67.01910791622522, 1.2410774634052546, 62.82091805281547]
# [47.17707725471029, 64.69137296529534, 5.032424133270979]
# [1, 2]
# 5 6
# --------
# Frame:  854
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [77.27984221680806, 1.0494171644632633, 61.75732862338042]
# [41.351406992054905, 62.62400989960401, 1.4894198748545768]
# [1, 2]
# 5 6
# --------
# Frame:  855
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [77.80159977326791, 0.0, 62.25610290773404]
# [41.430437623117214, 62.25610290773404, 0.0]
# [1, 2]
# 5 6
# --------
# Frame:  856
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [77.67552300236927, 1.517844327367269, 62.50666869259798]
# [34.650053198711994, 62.60183657056246, 1.121774272276805]
# [1, 2]
# 5 6
# --------
# Frame:  857
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [77.20784255690299, 2.4703547039475198, 62.644861321132154]
# [34.05658063158775, 63.33225988634886, 1.0200590083423333]
# [1, 2]
# 5 6
# --------
# Frame:  858
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [74.91996190429498, 2.0360034658358646, 62.790071970305576]
# [21.19240928049653, 62.74472879551542, 0.834727239747269]
# [1, 2]
# 5 6
# --------
# Frame:  859
# View:  1
# Prev idx:  5
# Candidate idx  [2, 5, 6]
# Prev idx:  6
# Candidate idx  [2, 5, 6]
# [65.72694668746911, 2.993964578096683, 61.693940135387656]
# [11.36176182475323, 62.888479937273914, 1.0874565322764027]
# [1, 2]
# 5 6
# --------
# Frame:  968
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [3.3651183587618365, 62.56625232941065, 23.052762158215046]
# [62.257572639638035, 2.996115148258515, 61.725721617539726]
# [0, 1]
# 6 5
# --------
# Frame:  969
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [0.0, 63.19072512900218, 22.83238432288934]
# [63.19072512900218, 0.0, 62.83832477014034]
# [0, 1]
# 6 5
# --------
# Frame:  970
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [9.441208969133022, 63.08532569156243, 26.76105423328968]
# [56.71448298390859, 0.90570696691672, 65.71978049648878]
# [0, 1]
# 6 5
# --------
# Frame:  971
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [3.432985372029436, 55.59185871567864, 21.36005582755957]
# [55.78962526179086, 1.5356424870208287, 64.99591007045446]
# [0, 1]
# 6 5
# --------
# Frame:  972
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [6.959953352570151, 54.676818353673205, 22.700245790899945]
# [51.99998652447875, 0.4656155044451738, 61.99210322065613]
# [0, 1]
# 6 5
# --------
# Frame:  973
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [11.1347959673462, 51.734609732452114, 23.246398957493977]
# [54.10626636880139, 1.1276380409223912, 63.19183059256428]
# [0, 1]
# 6 5
# --------
# Frame:  974
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [3.034303269229638, 54.066101065956246, 26.745276909464827]
# [54.74544225456432, 1.6460888361892638, 62.56240830035546]
# [0, 1]
# 6 5
# --------
# Frame:  975
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [0.0, 54.91529809268048, 26.007857643975278]
# [54.91529809268048, 0.0, 63.12418979435013]
# [0, 1]
# 6 5
# --------
# Frame:  976
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [3.840286553526918, 54.82691265399066, 21.73839644318781]
# [56.830049549539886, 3.3047177535601153, 57.501066830964426]
# [0, 1]
# 6 5
# --------
# Frame:  977
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [3.6423427334580665, 56.744953045000635, 21.3265030635282]
# [54.6323109937784, 3.0327501689585357, 57.88288309893165]
# [0, 1]
# 6 5
# --------
# Frame:  978
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [3.644050476929316, 54.815664759240086, 23.79900033132006]
# [54.40716698001592, 1.2947979094699407, 53.41689495895154]
# [0, 1]
# 6 5
# --------
# Frame:  979
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [1.658765278947659, 53.95729743144833, 25.560297520496906]
# [54.32401390803548, 1.8776612224487157, 53.22997488282048]
# [0, 1]
# 6 5
# --------
# Frame:  980
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [3.9418010365886564, 53.866728778641956, 24.7886081272975]
# [55.409946357114954, 1.8482886607257218, 54.94895748497966]
# [0, 1]
# 6 5
# --------
# Frame:  981
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [0.0, 55.29964716732502, 22.966218195855618]
# [55.29964716732502, 0.0, 54.008963402456196]
# [0, 1]
# 6 5
# --------
# Frame:  982
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [3.4376343362128887, 55.66762030554506, 11.853337450478321]
# [54.58443002846952, 2.2281720041273494, 50.97092848080091]
# [0, 1]
# 6 5
# --------
# Frame:  984
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [1.1626857326437647, 53.86851638125685, 25.92517994850492]
# [54.35236860818874, 2.457354345764869, 58.02545752681983]
# [0, 1]
# 6 5
# --------
# Frame:  985
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [3.192756482065679, 53.76778695577135, 20.348436216967038]
# [54.96293631372735, 1.7733906890528324, 52.541677357294624]
# [0, 1]
# 6 5
# --------
# Frame:  986
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [2.8398791858210015, 55.41760316276206, 16.54234969181319]
# [54.42539733270995, 2.318462029672586, 56.7688494554888]
# [0, 1]
# 6 5
# --------
# Frame:  987
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [0.0, 54.880084804856246, 16.93392514413557]
# [54.880084804856246, 0.0, 57.07788760988758]
# [0, 1]
# 6 5
# --------
# Frame:  988
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [10.237414556770371, 53.60534698014649, 14.320044418319295]
# [50.749136172808136, 2.4653393671107597, 54.19289200552381]
# [0, 1]
# 6 5
# --------
# Frame:  989
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [5.986637330948351, 49.42891930311154, 17.469614966844137]
# [53.14114669765322, 1.0330817996500394, 55.70568998769308]
# [0, 1]
# 6 5
# --------
# Frame:  990
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [3.5721827405863085, 53.12763371383055, 22.952398370449934]
# [55.3410453327621, 1.0000209384239638, 60.00422374417003]
# [0, 1]
# 6 5
# --------
# Frame:  991
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [7.115662999618321, 54.73906958659585, 26.04129698722122]
# [51.75986229661756, 1.4503945585053701, 60.951691990957045]
# [0, 1]
# 6 5
# --------
# Frame:  992
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [5.362332582903596, 50.08927042892155, 19.726344471224227]
# [49.39422832696866, 1.7845366838841865, 57.71467962536292]
# [0, 1]
# 6 5
# --------
# Frame:  993
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [0.0, 48.19044883100268, 21.32839169506079]
# [48.19044883100268, 0.0, 56.48605838064582]
# [0, 1]
# 6 5
# --------
# Frame:  994
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [11.620504986351499, 49.08067579586537, 21.309406578349762]
# [54.365904703497506, 2.0315255246674404, 61.217521745329485]
# [0, 1]
# 6 5
# --------
# Frame:  995
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [9.580563052676808, 54.79735166565157, 25.67975711884598]
# [52.13046704356869, 2.621963406411501, 61.84518291438237]
# [0, 1]
# 6 5
# --------
# Frame:  996
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [10.84815420028873, 52.21477876957028, 24.960193551217134]
# [56.25924283743669, 2.6964797031803007, 62.114560299003735]
# [0, 1]
# 6 5
# --------
# Frame:  997
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [4.412882671094476, 55.439436454325914, 24.040534116518803]
# [54.64210323946407, 2.1999396294928513, 59.19940295280554]
# [0, 1]
# 6 5
# --------
# Frame:  998
# View:  1
# Prev idx:  6
# Candidate idx  [6, 5, 2]
# Prev idx:  5
# Candidate idx  [6, 5, 2]
# [5.929916321371611, 54.11313572186881, 25.096104248928334]
# [54.35309121027016, 2.615921259881594, 60.924535313000284]
# [0, 1]
# 6 5
# --------
# Frame:  703
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [5.137580258724017, 69.40963636357814, 74.75230569029466]
# [72.77736279712273, 4.820539149909448, 5.7621943060404215]
# [0, 1]
# 1 2
# --------
# Frame:  704
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [4.643593504260748, 72.32485035950175, 77.08342559941305]
# [69.52332175866916, 4.259059360107551, 9.6050364575707]
# [0, 1]
# 1 2
# --------
# Frame:  705
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [0.0, 71.1156020929607, 75.22483658714172]
# [71.1156020929607, 0.0, 8.001792992632359]
# [0, 1]
# 1 2
# --------
# Frame:  710
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [3.874047624759185, 62.22764934952824, 68.65919741758934]
# [63.468115406540726, 5.801877502925121, 11.02677547893463]
# [0, 1]
# 1 2
# --------
# Frame:  711
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [0.0, 63.3672545430943, 69.9818675594452]
# [63.3672545430943, 0.0, 9.019533870407404]
# [0, 1]
# 1 2
# --------
# Frame:  712
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [2.070178515636004, 63.051875161341364, 70.1988747513447]
# [63.13336052124699, 2.94172186175218, 8.981669547943733]
# [0, 1]
# 1 2
# --------
# Frame:  792
# View:  3
# Prev idx:  1
# Candidate idx  [1, 3, 2]
# Prev idx:  3
# Candidate idx  [1, 3, 2]
# [5.600090686327372, 104.9375660140545, 103.60624577831]
# [106.4546925150431, 1.3704468791301434, 3.0177278499572706]
# [0, 1]
# 1 3
# --------
# Frame:  794
# View:  3
# Prev idx:  1
# Candidate idx  [1, 3, 2]
# Prev idx:  3
# Candidate idx  [1, 3, 2]
# [12.213907619508413, 105.52128061346518, 103.62893104218902]
# [97.19277239361635, 1.8027043701746526, 4.2032686942853985]
# [0, 1]
# 1 3
# --------
# Frame:  795
# View:  3
# Prev idx:  1
# Candidate idx  [1, 3, 2]
# Prev idx:  3
# Candidate idx  [1, 3, 2]
# [0.0, 97.36003781721378, 95.36621349620131]
# [97.36003781721378, 0.0, 3.4699615382422238]
# [0, 1]
# 1 3
# --------
# Frame:  805
# View:  3
# Prev idx:  1
# Candidate idx  [1, 3, 2]
# Prev idx:  3
# Candidate idx  [1, 3, 2]
# [7.835394023607175, 75.95609481976582, 74.36325002385256]
# [71.24873950494788, 1.2285330624152453, 3.534719061584045]
# [0, 1]
# 1 3
# --------
# Frame:  809
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [25.736351183305185, 84.40309394628574, 85.23130384584267]
# [65.45659167596546, 0.6590085956148612, 2.778139776717394]
# [0, 1]
# 1 2
# --------
# Frame:  810
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [14.971701325132297, 65.46587076276923, 66.98294140140598]
# [72.7088739538613, 0.888823393254708, 3.0371011797434244]
# [0, 1]
# 1 2
# --------
# Frame:  814
# View:  3
# Prev idx:  1
# Candidate idx  [1, 3, 2]
# Prev idx:  3
# Candidate idx  [1, 3, 2]
# [6.962968650632179, 70.39443992737394, 69.2541780067751]
# [66.02997087324277, 1.2350058876551115, 3.0389363108537135]
# [0, 1]
# 1 3
# --------
# Frame:  816
# View:  3
# Prev idx:  1
# Candidate idx  [1, 3, 2]
# Prev idx:  3
# Candidate idx  [1, 3, 2]
# [3.7629077991422935, 68.14702222935664, 66.72350037976717]
# [67.8957674020949, 1.0185607576217406, 3.221658733792794]
# [0, 1]
# 1 3
# --------
# Frame:  817
# View:  3
# Prev idx:  1
# Candidate idx  [1, 3, 2]
# Prev idx:  3
# Candidate idx  [1, 3, 2]
# [3.044596277177334, 67.89850390329957, 66.72344385727476]
# [67.74368658575874, 2.1295470820787625, 4.0819276063106]
# [0, 1]
# 1 3
# --------
# Frame:  822
# View:  3
# Prev idx:  1
# Candidate idx  [1, 3, 2]
# Prev idx:  3
# Candidate idx  [1, 3, 2]
# [1.9869547959130545, 64.21336279274561, 63.0912040181649]
# [63.6147113871307, 1.4293105541131434, 2.9665179416919365]
# [0, 1]
# 1 3
# --------
# Frame:  823
# View:  3
# Prev idx:  1
# Candidate idx  [1, 3, 2]
# Prev idx:  3
# Candidate idx  [1, 3, 2]
# [1.9193966009486945, 63.6379636022716, 62.21679892916328]
# [62.808502999062725, 1.2550935225609021, 2.939994066189497]
# [0, 1]
# 1 3
# --------
# Frame:  832
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [10.795500475053604, 54.76803969591856, 56.533163790901504]
# [61.44653513817451, 1.9761439292476728, 3.4775636945015345]
# [0, 1]
# 1 2
# --------
# Frame:  834
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [9.938359435265644, 59.39700157883075, 61.1138491766193]
# [58.956915525767286, 1.0847570695556128, 3.0789702051343064]
# [0, 1]
# 1 2
# --------
# Frame:  866
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [1.4530229111894584, 73.43056903626675, 77.27333291228383]
# [73.75684454062811, 1.7986641556788714, 14.607581296887917]
# [0, 1]
# 1 2
# --------
# Frame:  867
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [0.0, 73.52187585276671, 77.19144804575123]
# [73.52187585276671, 0.0, 14.458517877814861]
# [0, 1]
# 1 2
# --------
# Frame:  920
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [8.035796899252977, 82.01435784651683, 86.82271022712573]
# [85.96270558620111, 1.9712045244299448, 13.449586746211235]
# [0, 1]
# 1 2
# --------
# Frame:  921
# View:  3
# Prev idx:  1
# Candidate idx  [1, 2, 3]
# Prev idx:  2
# Candidate idx  [1, 2, 3]
# [0.0, 86.69139029410405, 91.48590585302848]
# [86.69139029410405, 0.0, 13.258733971760822]
# [0, 1]
# 1 2

# %%
def view_index_consistency(unstruct_det, view):
    '''
    Method that indexes the detections according to ReID and last frame

    unstruct_det: list of all the detections in a single frame PER VIEW
    '''
    indexed_det_list = []

    for i, detection in enumerate(unstruct_det): #For each frame, get detections
        idx_frame_keypoint_list = [None, None] #[agent_1, agent_2]
        assert len(detection) != 0, f'Cannot proceed! No people were detected in frame {i}, view {view}'


        if len(detection) == 1:
            if not indexed_det_list:
                print('First frame only has one detection!')
            else:
                if  None not in indexed_det_list[-1]:
                    match_id = identify_keypoint_index(detection, indexed_det_list[-1])
                    idx_frame_keypoint_list[match_id] = detection[0]
                else:
                    #Find similarity
                    none_idx = indexed_det_list[-1].index(None)
                    single_idx = 1 if none_idx == 0 else 0
                    if indexed_det_list[-1][single_idx]['idx'] == detection[0]['idx']:
                        idx_frame_keypoint_list[single_idx] = detection[0]
                    elif calc_keypoint_overlap(idx_frame_keypoint_list[single_idx]['keypoints'], detection['keypoints']) < 10:
                        idx_frame_keypoint_list[single_idx] = detection[0]
                    else:
                        idx_frame_keypoint_list[none_idx] = detection[0]


        elif len(detection) == 2:
            idx_a = detection[0]['idx']
            idx_b = detection[1]['idx']
            if not indexed_det_list:
                idx_frame_keypoint_list[0] = detection[0]
                idx_frame_keypoint_list[1] = detection[1]
            else:
                if None not in indexed_det_list[-1]:
                    idx_last_a = indexed_det_list[-1][0]['idx']
                    idx_last_b = indexed_det_list[-1][1]['idx']
                    unidentified_detections = [] #stores the detections that changed their idx score, compared to the last frame
                    for d in detection:
                        if d['idx'] == idx_last_a:
                            idx_frame_keypoint_list[0] = d
                        elif d['idx'] == idx_last_b:
                            idx_frame_keypoint_list[1] = d
                        else:
                            unidentified_detections.append(d)
                else:
                    none_idx = indexed_det_list[-1].index(None)
                    single_idx = 1 if none_idx == 0 else 0
                    match_id = identify_keypoint_index([indexed_det_list[-1][single_idx]], detection)
                    rem_match_id = 1 if match_id == 0 else 0
                    idx_frame_keypoint_list[single_idx] = detection[match_id]
                    idx_frame_keypoint_list[none_idx] = detection[rem_match_id]
                    
                if unidentified_detections:
                    #check keypoint overlap
                    if  None not in indexed_det_list[-1]:
                        for unident in unidentified_detections:
                            match_id = identify_keypoint_index([unident], indexed_det_list[-1])
                            if idx_frame_keypoint_list[match_id] != None:
                                if unident['score'] > idx_frame_keypoint_list[match_id]['score']:
                                    idx_frame_keypoint_list[match_id] = unident
                            else:
                                #unident['idx'] = indexed_det_list[-1][match_id]['idx']
                                idx_frame_keypoint_list[match_id] = unident
                            
        elif len(detection) > 2:
            print('Should not happen')

        indexed_det_list.append(idx_frame_keypoint_list)
    return indexed_det_list

# %%
ice_keypoints = []
for id_v, det_view in enumerate(corrected_key_view_list):
    ice_keypoints.append(view_index_consistency(det_view, id_v))

# %%
def get_missing_frames(key_list, search_idx):
    #Finds missing detections of a single individual per view
    miss= []
    for n_frame, frame_det in enumerate(key_list):

        assert len(frame_det) == 2
        if frame_det[search_idx] == None:
            miss.append(n_frame)
    return miss

# %%
def get_missing_frame_ranges(miss_list):
    range_list = []
    miss_det_range = []
    for idx, f_miss in enumerate(miss_list):
        if not miss_det_range:
            miss_det_range.append(f_miss)
        elif f_miss == (miss_det_range[-1] + 1):
            miss_det_range.append(f_miss)
        else:
            range_list.append(miss_det_range.copy())
            miss_det_range.clear()
            miss_det_range.append(f_miss)
              
    range_list.append(miss_det_range.copy())
        

    return range_list

# %%
a = get_missing_frames(ice_keypoints[1], 0)
z = get_missing_frame_ranges(a)
print(a)
print(z)
# Out:
# [424]
# [[424]]

# %%
def interpolate_keypoints(start_point, end_point, n_interpol):
    assert (len(start_point) == len(end_point)), f'Interpolation lists need to be of the same size'
    interpolation_list = []

    for i in range(1, n_interpol):
        #For each missing point
        keypoints = []
       
        for start_, end_ in zip(start_point, end_point):
            #For each keypoint in list
            start = start_
            end = end_

            rng = abs(start-end)
            stride = rng/n_interpol
            if start > end:
                value = start - (stride * i)
            else:
                value = start + (stride * i)
            keypoints.append(value)
        
        interpolation_list.append(keypoints.copy())

    return interpolation_list

# %%
interpolate_keypoints([10, 20, 30], [20, 30, 40], 3)
# Out:
# [[13.333333333333334, 23.333333333333332, 33.333333333333336],
#  [16.666666666666668, 26.666666666666668, 36.666666666666664]]

# %%
def interpolate_missing_detections(keypoints):
    n_people = 2
    inter_keypoints = copy.deepcopy(keypoints)

    for person_id in range(n_people):
        for view in range(len(keypoints)):
            #Get missing detections of *person_id* in *view*
                print(f'View: {view} - Person {person_id}')
                missing_frame_list = get_missing_frames(keypoints[view], person_id)

                if missing_frame_list:
                    pers_miss_range = get_missing_frame_ranges(missing_frame_list)
                    pooled_points = []
                    print(pers_miss_range)
                    for range_f in pers_miss_range:
                        start = range_f[0]
                        end = range_f[-1]
                        pooled_points = interpolate_keypoints(keypoints[view][start-1][person_id]['keypoints'].copy(), keypoints[view][end+1][person_id]['keypoints'].copy(), len(range_f)+1)
                        
                        base_inst = copy.deepcopy(keypoints[view][start-1][person_id])
                        base_img_name = int(base_inst['image_id'].split('.png')[0])

                        assert len(range_f) == len(pooled_points)

                        for id, miss_frame in enumerate(range_f):
                            assert inter_keypoints[view][miss_frame][person_id] == None

                            inter_keypoints[view][miss_frame][person_id] = copy.deepcopy(base_inst)
                            frame_numb = '{0:05d}'.format(base_img_name + (id+1)) + '.png'

                            inter_keypoints[view][miss_frame][person_id]['image_id'] = frame_numb
                            inter_keypoints[view][miss_frame][person_id]['keypoints'] = pooled_points[id].copy()
    return inter_keypoints

# %%
interpool_keypoints = interpolate_missing_detections(ice_keypoints)
# Out:
# View: 0 - Person 0
# View: 1 - Person 0
# [[424]]
# View: 2 - Person 0
# View: 3 - Person 0
# [[278, 279]]
# View: 0 - Person 1
# [[565], [572, 573, 574, 575, 576], [655], [659, 660, 661, 662, 663, 664], [677], [688], [691, 692, 693, 694], [871, 872, 873], [899], [901, 902, 903], [929], [936, 937, 938, 939], [942], [952], [959, 960, 961, 962, 963], [966, 967, 968, 969], [979]]
# View: 1 - Person 1
# View: 2 - Person 1
# [[40, 41, 42, 43, 44, 45, 46, 47, 48], [197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217, 218, 219, 220, 221, 222, 223, 224, 225, 226, 227, 228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254, 255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268, 269, 270, 271, 272, 273, 274, 275, 276, 277, 278, 279, 280, 281, 282, 283, 284, 285, 286, 287, 288, 289, 290, 291, 292, 293, 294, 295, 296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 329, 330, 331, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347, 348, 349, 350, 351, 352, 353, 354, 355, 356, 357, 358, 359, 360, 361, 362, 363, 364, 365, 366, 367, 368, 369, 370, 371, 372, 373, 374, 375, 376, 377, 378, 379, 380, 381, 382, 383, 384, 385, 386, 387, 388, 389, 390, 391, 392, 393, 394, 395, 396, 397, 398, 399, 400, 401, 402, 403, 404, 405, 406, 407, 408, 409, 410, 411, 412, 413, 414, 415, 416, 417, 418, 419, 420, 421, 422, 423, 424, 425, 426, 427, 428, 429, 430, 431, 432, 433, 434, 435, 436, 437, 438, 439, 440, 441, 442, 443, 444, 445, 446, 447, 448, 449, 450, 451, 452, 453, 454, 455, 456, 457, 458, 459, 460, 461, 462, 463, 464, 465, 466, 467, 468, 469, 470, 471, 472, 473, 474, 475, 476, 477, 478, 479, 480, 481, 482, 483, 484, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 500, 501, 502, 503, 504, 505, 506, 507, 508, 509, 510, 511, 512, 513, 514, 515, 516, 517, 518, 519, 520, 521, 522, 523, 524, 525, 526, 527, 528, 529, 530, 531, 532, 533, 534, 535, 536, 537, 538, 539, 540, 541, 542, 543, 544, 545, 546, 547, 548, 549, 550, 551, 552, 553, 554, 555, 556, 557, 558, 559, 560, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571, 572, 573, 574, 575, 576, 577, 578, 579, 580, 581, 582, 583, 584, 585], [604, 605, 606, 607, 608, 609, 610], [612, 613, 614, 615, 616, 617, 618, 619, 620, 621, 622, 623, 624, 625, 626, 627, 628, 629, 630, 631, 632, 633, 634], [636, 637, 638, 639, 640], [658, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670], [674, 675, 676, 677, 678, 679, 680, 681, 682, 683, 684, 685, 686, 687, 688, 689, 690, 691, 692, 693, 694, 695, 696, 697, 698, 699, 700, 701, 702, 703, 704, 705, 706, 707, 708], [710, 711, 712, 713, 714, 715, 716, 717, 718, 719], [721]]
# View: 3 - Person 1
# [[650, 651, 652, 653], [658, 659, 660, 661, 662, 663, 664, 665, 666, 667, 668, 669, 670, 671, 672], [697], [895], [901]]

# %% [markdown]
# View 0 -> 0:Parent, 1:Child<br>
# View 1 -> 0:Child,  1:Parent<br>
# View 2 -> 0:Parent, 1:Child<br>
# View 3 -> 0:Parent, 1:Child<br>

# %%
print(interpool_keypoints[0][658][1])
print(interpool_keypoints[0][659][1])
print(interpool_keypoints[0][660][1])
print(interpool_keypoints[0][661][1])
print(interpool_keypoints[0][662][1])
print(interpool_keypoints[0][663][1])
print(interpool_keypoints[0][664][1])
print(interpool_keypoints[0][665][1])
# Out:
# {'image_id': '00659.png', 'category_id': 1, 'keypoints': [408.39886474609375, 221.78453063964844, 0.8888577222824097, 406.6169128417969, 214.65667724609375, 0.8678443431854248, 403.052978515625, 218.22061157226562, 0.8416237831115723, 379.8874816894531, 228.91236877441406, 0.3592364490032196, 385.2333679199219, 230.6943359375, 0.6958558559417725, 390.5792541503906, 236.04022216796875, 0.6171960830688477, 374.5415954589844, 252.077880859375, 0.8521766662597656, 395.9251403808594, 264.5516052246094, 0.5419926047325134, 385.2333679199219, 278.8072814941406, 0.9980472326278687, 415.5267333984375, 275.2433776855469, 0.4356701076030731, 415.5267333984375, 271.679443359375, 0.9244371652603149, 397.70709228515625, 293.06298828125, 0.7367123365402222, 379.8874816894531, 307.31866455078125, 0.8320669531822205, 431.5643615722656, 285.9351501464844, 0.6628293991088867, 404.8349609375, 314.446533203125, 0.6772988438606262, 463.6396789550781, 293.06298828125, 0.6470603346824646, 436.9102478027344, 339.39398193359375, 0.7137311697006226, 388.79730224609375, 191.49118041992188, 0.8370314836502075, 379.8874816894531, 236.04022216796875, 0.8153524994850159, 385.2333679199219, 300.1908264160156, 0.7934048175811768, 491.26007080078125, 283.26220703125, 0.5748649835586548, 486.80517578125, 335.8300476074219, 0.3893064558506012, 488.5871276855469, 280.5892639160156, 0.5605224370956421, 481.45928955078125, 350.08575439453125, 0.4997289776802063, 472.54949951171875, 298.40887451171875, 0.776777446269989, 442.2561340332031, 342.9579162597656, 0.6278767585754395], 'score': 2.4746389389038086, 'box': [349.3001379879872, 170.50580964658695, 119.39477186562817, 179.4244677082387], 'idx': 2}
# {'image_id': '00660.png', 'category_id': 1, 'keypoints': [408.1393737792969, 221.58822413853235, 0.8850904277392796, 406.6119864327567, 214.91810171944755, 0.8395063621657235, 402.9966517857143, 217.97290257045202, 0.8511141112872532, 377.81542532784596, 227.6977996826172, 0.3566330543586186, 386.6016278948103, 229.78573608398438, 0.704980628831046, 386.6995370047433, 235.7692631312779, 0.6326769675527301, 375.7556457519531, 250.63689749581474, 0.843021537576403, 392.9633309500558, 264.131338936942, 0.5311302670410701, 385.76082502092635, 278.31236049107144, 0.9873483095850263, 415.0897783551897, 273.29571533203125, 0.4623501982007708, 415.93058122907365, 271.0817173549107, 0.9254766872950962, 396.4525887625558, 293.61448451450894, 0.6933570504188538, 380.61810302734375, 307.23497227260043, 0.8126939109393528, 431.0784606933594, 285.82330322265625, 0.658946658883776, 407.8872767857143, 313.62484305245533, 0.6843261633600507, 463.8966718401228, 293.053946358817, 0.6682248030390058, 442.1068028041295, 335.8491734095982, 0.6653878475938525, 388.53536115373885, 190.85794721330916, 0.8388666169984, 379.7773001534598, 235.20872715541296, 0.8068505014692035, 384.9200221470424, 300.2845938546317, 0.7941931486129761, 491.4950430733817, 282.971670968192, 0.6263601694788251, 485.99495588030135, 331.67330060686385, 0.4275281769888742, 488.6434108189174, 280.68057686941967, 0.6041036588805062, 481.1324986049107, 345.2938145228795, 0.5014920234680176, 472.3744637625558, 298.4769374302455, 0.7736478447914124, 447.529793875558, 338.6237051827567, 0.5907125132424491], 'score': 2.4746389389038086, 'box': [349.3001379879872, 170.50580964658695, 119.39477186562817, 179.4244677082387], 'idx': 2}
# {'image_id': '00661.png', 'category_id': 1, 'keypoints': [407.8798828125, 221.3919176374163, 0.8813231331961495, 406.60706002371654, 215.17952619280135, 0.8111683811460223, 402.94032505580356, 217.7251935686384, 0.8606044394629342, 375.74336896623885, 226.4832305908203, 0.3540296597140176, 387.96988786969865, 228.87713623046875, 0.7141054017203194, 382.81981985909596, 235.49830409458704, 0.6481578520366124, 376.9696960449219, 249.19591413225447, 0.8338664088930402, 390.0015215192522, 263.71107264927457, 0.5202679293496268, 386.2882821219308, 277.8174394880022, 0.976649386542184, 414.652823311942, 271.3480529785156, 0.48903028879846844, 416.3344290597098, 270.48399135044644, 0.9265162093298775, 395.19808523995533, 294.16598074776783, 0.6500017642974854, 381.3487243652344, 307.15127999441967, 0.7933208686964852, 430.5925598144531, 285.7114562988281, 0.6550639186586652, 410.93959263392856, 312.8031529017857, 0.6913534828594753, 464.1536647251674, 293.04490443638394, 0.6893892713955471, 447.30335780552457, 332.3043648856027, 0.6170445254870823, 388.27342006138394, 190.22471400669642, 0.8407017503465924, 379.66711861746654, 234.37723214285714, 0.7983485034533909, 384.60667637416293, 300.3783612932478, 0.7949814796447754, 491.73001534598217, 282.68113490513394, 0.6778553553989956, 485.1847359793527, 327.5165536063058, 0.4657498981271471, 488.69969395228793, 280.77188982282365, 0.6476848806653704, 480.8057076590402, 340.5018746512277, 0.5032550692558289, 472.19942801339283, 298.5450003487723, 0.7705182433128357, 452.80345371791293, 334.2894941057478, 0.5535482679094587], 'score': 2.4746389389038086, 'box': [349.3001379879872, 170.50580964658695, 119.39477186562817, 179.4244677082387], 'idx': 2}
# {'image_id': '00662.png', 'category_id': 1, 'keypoints': [407.6203918457031, 221.19561113630022, 0.8775558386530194, 406.60213361467635, 215.44095066615515, 0.782830400126321, 402.88399832589283, 217.47748456682478, 0.8700947676386152, 373.6713126046317, 225.26866149902344, 0.3514262650694166, 389.33814784458707, 227.96853637695312, 0.7232301746095929, 378.94010271344865, 235.2273450578962, 0.6636387365204948, 378.1837463378906, 247.7549307686942, 0.8247112802096775, 387.03971208844865, 263.29080636160717, 0.5094055916581836, 386.8157392229353, 277.322518484933, 0.9659504634993417, 414.2158682686942, 269.400390625, 0.5157103793961662, 416.73827689034596, 269.88626534598217, 0.9275557313646589, 393.9435817173549, 294.7174769810268, 0.6066464781761169, 382.079345703125, 307.06758771623885, 0.7739478264536177, 430.1066589355469, 285.599609375, 0.6511811784335545, 413.99190848214283, 311.98146275111606, 0.6983808023588998, 464.41065761021207, 293.0358625139509, 0.7105537397520882, 452.49991280691967, 328.75955636160717, 0.5687012033803123, 388.01147896902904, 189.5914808000837, 0.842536883694785, 379.5569370814732, 233.54573713030135, 0.7898465054375785, 384.29333060128346, 300.47212873186385, 0.7957698106765747, 491.9649876185826, 282.3905988420759, 0.7293505413191659, 484.37451607840404, 323.3598066057478, 0.5039716192654201, 488.75597708565846, 280.8632027762277, 0.6912661024502346, 480.47891671316967, 335.7099347795759, 0.5050181150436401, 472.0243922642299, 298.6130632672991, 0.767388641834259, 458.07711356026783, 329.95528302873885, 0.5163840225764683], 'score': 2.4746389389038086, 'box': [349.3001379879872, 170.50580964658695, 119.39477186562817, 179.4244677082387], 'idx': 2}
# {'image_id': '00663.png', 'category_id': 1, 'keypoints': [407.36090087890625, 220.99930463518416, 0.8737885441098895, 406.59720720563615, 215.70237513950892, 0.7544924191066197, 402.82767159598217, 217.22977556501115, 0.8795850958142962, 371.59925624302457, 224.05409240722656, 0.3488228704248156, 390.70640781947543, 227.0599365234375, 0.7323549474988665, 375.06038556780135, 234.95638602120536, 0.6791196210043771, 379.3977966308594, 246.31394740513392, 0.8155561515263149, 384.0779026576451, 262.8705400739397, 0.4985432539667402, 387.3431963239397, 276.82759748186385, 0.9552515404564994, 413.77891322544644, 267.4527282714844, 0.5423904699938638, 417.14212472098217, 269.28853934151783, 0.9285952533994403, 392.6890781947545, 295.2689732142857, 0.5632911920547485, 382.8099670410156, 306.983895438058, 0.7545747842107501, 429.6207580566406, 285.4877624511719, 0.6472984382084438, 417.04422433035717, 311.15977260044644, 0.7054081218583244, 464.6676504952567, 293.02682059151783, 0.7317182081086295, 457.6964678083147, 325.2147478376116, 0.5203578812735421, 387.7495378766741, 188.958247593471, 0.8443720170429775, 379.4467555454799, 232.71424211774553, 0.781344507421766, 383.97998482840404, 300.5658961704799, 0.796558141708374, 492.199959891183, 282.10006277901783, 0.7808457272393363, 483.56429617745533, 319.2030596051897, 0.542193340403693, 488.81226021902904, 280.9545157296317, 0.7348473242350987, 480.1521257672991, 330.9179949079241, 0.5067811608314514, 471.849356515067, 298.6811261858259, 0.7642590403556824, 463.3507734026228, 325.6210719517299, 0.479219777243478], 'score': 2.4746389389038086, 'box': [349.3001379879872, 170.50580964658695, 119.39477186562817, 179.4244677082387], 'idx': 2}
# {'image_id': '00664.png', 'category_id': 1, 'keypoints': [407.1014099121094, 220.80299813406808, 0.8700212495667594, 406.59228079659596, 215.96379961286272, 0.7261544380869185, 402.77134486607144, 216.98206656319755, 0.8890754239899772, 369.5271998814174, 222.8395233154297, 0.34621947578021456, 392.07466779436385, 226.15133666992188, 0.74147972038814, 371.18066842215404, 234.68542698451452, 0.6946005054882595, 380.6118469238281, 244.87296404157365, 0.8064010228429522, 381.11609322684154, 262.4502737862723, 0.4876809162752969, 387.8706534249442, 276.33267647879467, 0.944552617413657, 413.34195818219865, 265.50506591796875, 0.5690705605915615, 417.5459725516183, 268.69081333705356, 0.9296347754342216, 391.43457467215404, 295.82046944754467, 0.5199359059333801, 383.54058837890625, 306.9002031598772, 0.7352017419678825, 429.1348571777344, 285.37591552734375, 0.6434156979833331, 420.09654017857144, 310.3380824497768, 0.7124354413577488, 464.92464338030135, 293.0177786690848, 0.7528826764651707, 462.8930228097098, 321.66993931361606, 0.47201455916677204, 387.4875967843192, 188.32501438685827, 0.84620715039117, 379.3365740094866, 231.88274710518974, 0.7728425094059536, 383.66663905552457, 300.65966360909596, 0.7973464727401733, 492.43493216378346, 281.8095267159598, 0.8323409131595066, 482.7540762765067, 315.0463126046317, 0.5804150615419661, 488.86854335239957, 281.0458286830357, 0.7784285460199629, 479.82533482142856, 326.1260550362723, 0.5085442066192627, 471.67432076590404, 298.7491891043527, 0.7611294388771057, 468.6244332449777, 321.28686087472096, 0.4420555319104876], 'score': 2.4746389389038086, 'box': [349.3001379879872, 170.50580964658695, 119.39477186562817, 179.4244677082387], 'idx': 2}
# {'image_id': '00665.png', 'category_id': 1, 'keypoints': [406.8419189453125, 220.60669163295202, 0.8662539550236293, 406.5873543875558, 216.2252240862165, 0.6978164570672172, 402.7150181361607, 216.73435756138392, 0.8985657521656581, 367.4551435198103, 221.6249542236328, 0.3436160811356136, 393.4429277692522, 225.24273681640625, 0.7506044932774135, 367.3009512765067, 234.41446794782365, 0.7100813899721419, 381.8258972167969, 243.4319806780134, 0.7972458941595895, 378.15428379603793, 262.0300074986049, 0.47681857858385357, 388.39811052594865, 275.83775547572543, 0.9338536943708147, 412.9050031389509, 263.5574035644531, 0.5957506511892592, 417.9498203822545, 268.0930873325893, 0.9306742974690029, 390.18007114955356, 296.37196568080356, 0.4765806198120117, 384.2712097167969, 306.81651088169644, 0.7158286997250148, 428.6489562988281, 285.2640686035156, 0.6395329577582223, 423.1488560267857, 309.51639229910717, 0.7194627608571734, 465.18163626534596, 293.0087367466518, 0.7740471448217119, 468.0895778111049, 318.1251307896205, 0.4236712370600019, 387.2256556919643, 187.69178118024553, 0.8480422837393624, 379.2263924734933, 231.05125209263392, 0.7643405113901411, 383.3532932826451, 300.75343104771207, 0.7981348037719727, 492.66990443638394, 281.5189906529018, 0.883836099079677, 481.943856375558, 310.88956560407365, 0.618636782680239, 488.9248264857701, 281.1371416364397, 0.822009767804827, 479.498543875558, 321.3341151646205, 0.510307252407074, 471.49928501674106, 298.8172520228795, 0.757999837398529, 473.8980930873326, 316.95264979771207, 0.4048912865774972], 'score': 2.4746389389038086, 'box': [349.3001379879872, 170.50580964658695, 119.39477186562817, 179.4244677082387], 'idx': 2}
# {'image_id': '00666.png', 'category_id': 1, 'keypoints': [406.5824279785156, 220.41038513183594, 0.8624866604804993, 406.5824279785156, 216.4866485595703, 0.6694784760475159, 402.65869140625, 216.4866485595703, 0.9080560803413391, 365.3830871582031, 220.41038513183594, 0.3410126864910126, 394.8111877441406, 224.33413696289062, 0.759729266166687, 363.4212341308594, 234.1435089111328, 0.7255622744560242, 383.0399475097656, 241.99099731445312, 0.7880907654762268, 375.1924743652344, 261.6097412109375, 0.4659562408924103, 388.9255676269531, 275.34283447265625, 0.9231547713279724, 412.4680480957031, 261.6097412109375, 0.6224307417869568, 418.3536682128906, 267.495361328125, 0.9317138195037842, 388.9255676269531, 296.9234619140625, 0.4332253336906433, 385.0018310546875, 306.7328186035156, 0.6964556574821472, 428.1630554199219, 285.1522216796875, 0.6356502175331116, 426.201171875, 308.6947021484375, 0.7264900803565979, 465.4386291503906, 292.99969482421875, 0.7952116131782532, 473.2861328125, 314.580322265625, 0.3753279149532318, 386.9637145996094, 187.0585479736328, 0.8498774170875549, 379.1162109375, 230.21975708007812, 0.7558385133743286, 383.0399475097656, 300.8471984863281, 0.798923134803772, 492.9048767089844, 281.22845458984375, 0.9353312849998474, 481.1336364746094, 306.7328186035156, 0.656858503818512, 488.9811096191406, 281.22845458984375, 0.8655909895896912, 479.1717529296875, 316.54217529296875, 0.5120702981948853, 471.3242492675781, 298.88531494140625, 0.7548702359199524, 479.1717529296875, 312.6184387207031, 0.36772704124450684], 'score': 2.6622684001922607, 'box': [344.26059305543663, 181.9920509066122, 157.98556072771248, 149.44037619273357], 'idx': 4}

# %%
keypoint_string='''
{
    "version":1.1,
    "people":[
    {"pose_keypoints_2d":[]
    },
    {"pose_keypoints_2d":[]
    }
    ]
}
'''

def save_json(folder, file, temp):
    with open(f'{folder}/{file}_keypoints.json', 'w') as f:
        json.dump(temp, f)
    f.close()

# %%
json_string = json.loads(keypoint_string)

save_json('00', 'asd', json_string)

# %%
#for view in range(len(interpool_keypoints)):
for frame in interpool_keypoints[3]:
    json_string = json.loads(keypoint_string)
    
    for i_d, det in enumerate(frame):
        #i = 0
        #if i_d == 0:
            #i = 1
        frame_name = det['image_id'].split('.png')[0]
        json_string['people'][i_d]['pose_keypoints_2d'] = copy.deepcopy(det['keypoints'])
    save_json('03', frame_name, json_string)
